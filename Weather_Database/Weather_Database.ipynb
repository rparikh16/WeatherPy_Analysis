# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_wdesc = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Weather Description": city_wdesc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | klaksvik
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | noyabrsk
# Processing Record 5 of Set 1 | virginia beach
# Processing Record 6 of Set 1 | xixiang
# Processing Record 7 of Set 1 | kapuskasing
# Processing Record 8 of Set 1 | yulara
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | lorengau
# Processing Record 11 of Set 1 | buala
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | sale
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | kolondieba
# Processing Record 16 of Set 1 | mlimba
# Processing Record 17 of Set 1 | sechura
# Processing Record 18 of Set 1 | isangel
# Processing Record 19 of Set 1 | port hardy
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | yarada
# Processing Record 22 of Set 1 | butembo
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | fare
# Processing Record 25 of Set 1 | socorro
# Processing Record 26 of Set 1 | bairiki
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | clyde river
# Processing Record 33 of Set 1 | roebourne
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | emilio carranza
# Processing Record 38 of Set 1 | avera
# Processing Record 39 of Set 1 | sarangani
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | almenevo
# City not found. Skipping...
# Processing Record 43 of Set 1 | havelock
# Processing Record 44 of Set 1 | san patricio
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | provideniya
# Processing Record 49 of Set 1 | zhuhai
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 1 of Set 2 | arbuzynka
# Processing Record 2 of Set 2 | safford
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | torbay
# Processing Record 5 of Set 2 | salalah
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | korla
# Processing Record 8 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | kimberley
# Processing Record 11 of Set 2 | manggar
# Processing Record 12 of Set 2 | aksu
# Processing Record 13 of Set 2 | lagoa
# Processing Record 14 of Set 2 | sibolga
# Processing Record 15 of Set 2 | saskylakh
# Processing Record 16 of Set 2 | batticaloa
# Processing Record 17 of Set 2 | saint-pierre
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | yerbogachen
# Processing Record 21 of Set 2 | olafsvik
# Processing Record 22 of Set 2 | porto novo
# Processing Record 23 of Set 2 | nolinsk
# Processing Record 24 of Set 2 | vao
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | labuhan
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | praia
# Processing Record 29 of Set 2 | karratha
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | narsaq
# Processing Record 32 of Set 2 | lebedinyy
# Processing Record 33 of Set 2 | presidencia roque saenz pena
# Processing Record 34 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 2 | manicore
# Processing Record 36 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 2 | lebu
# Processing Record 38 of Set 2 | acapulco
# Processing Record 39 of Set 2 | pavda
# City not found. Skipping...
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | ancud
# Processing Record 42 of Set 2 | esperance
# Processing Record 43 of Set 2 | bluff
# Processing Record 44 of Set 2 | tuatapere
# Processing Record 45 of Set 2 | sao filipe
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | rio grande
# Processing Record 48 of Set 2 | bobrovka
# Processing Record 49 of Set 2 | vila franca do campo
# Processing Record 50 of Set 2 | yellowknife
# Processing Record 1 of Set 3 | bardsir
# Processing Record 2 of Set 3 | sambava
# Processing Record 3 of Set 3 | chuy
# Processing Record 4 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 3 | lewisville
# Processing Record 6 of Set 3 | ishim
# Processing Record 7 of Set 3 | kawalu
# Processing Record 8 of Set 3 | hilo
# Processing Record 9 of Set 3 | dikson
# Processing Record 10 of Set 3 | chumikan
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | atuona
# Processing Record 13 of Set 3 | los llanos de aridane
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | sao joao da barra
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | brae
# Processing Record 18 of Set 3 | puerto ayora
# Processing Record 19 of Set 3 | henties bay
# Processing Record 20 of Set 3 | rocha
# Processing Record 21 of Set 3 | hobart
# Processing Record 22 of Set 3 | erenhot
# Processing Record 23 of Set 3 | alta floresta
# Processing Record 24 of Set 3 | trat
# Processing Record 25 of Set 3 | bengkulu
# Processing Record 26 of Set 3 | tuktoyaktuk
# Processing Record 27 of Set 3 | gigmoto
# Processing Record 28 of Set 3 | abilene
# Processing Record 29 of Set 3 | eureka
# Processing Record 30 of Set 3 | bonito
# Processing Record 31 of Set 3 | kemlya
# Processing Record 32 of Set 3 | russell
# Processing Record 33 of Set 3 | rio rancho
# Processing Record 34 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 3 | iqaluit
# Processing Record 36 of Set 3 | port-gentil
# Processing Record 37 of Set 3 | nautla
# Processing Record 38 of Set 3 | bredasdorp
# Processing Record 39 of Set 3 | dwarka
# Processing Record 40 of Set 3 | kruisfontein
# Processing Record 41 of Set 3 | srednekolymsk
# Processing Record 42 of Set 3 | marrakesh
# Processing Record 43 of Set 3 | jinchengjiang
# City not found. Skipping...
# Processing Record 44 of Set 3 | westport
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | prenzlau
# Processing Record 47 of Set 3 | sioux lookout
# Processing Record 48 of Set 3 | koutiala
# Processing Record 49 of Set 3 | alice springs
# Processing Record 50 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 4 | ilulissat
# Processing Record 2 of Set 4 | burdur
# Processing Record 3 of Set 4 | lompoc
# Processing Record 4 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 4 | plettenberg bay
# Processing Record 6 of Set 4 | vardo
# Processing Record 7 of Set 4 | vite
# Processing Record 8 of Set 4 | nome
# Processing Record 9 of Set 4 | gainesville
# Processing Record 10 of Set 4 | brazzaville
# Processing Record 11 of Set 4 | esna
# Processing Record 12 of Set 4 | vila velha
# Processing Record 13 of Set 4 | kununurra
# Processing Record 14 of Set 4 | rio gallegos
# Processing Record 15 of Set 4 | airai
# Processing Record 16 of Set 4 | hasaki
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | westbrook
# Processing Record 19 of Set 4 | katherine
# Processing Record 20 of Set 4 | micheweni
# Processing Record 21 of Set 4 | palmer
# Processing Record 22 of Set 4 | jasper
# Processing Record 23 of Set 4 | asau
# Processing Record 24 of Set 4 | georgetown
# Processing Record 25 of Set 4 | new norfolk
# Processing Record 26 of Set 4 | tsarychanka
# Processing Record 27 of Set 4 | mao
# Processing Record 28 of Set 4 | verkhnyaya inta
# Processing Record 29 of Set 4 | formosa
# Processing Record 30 of Set 4 | constitucion
# Processing Record 31 of Set 4 | fairbanks
# Processing Record 32 of Set 4 | hvide sande
# Processing Record 33 of Set 4 | te anau
# Processing Record 34 of Set 4 | calca
# Processing Record 35 of Set 4 | harer
# Processing Record 36 of Set 4 | amga
# Processing Record 37 of Set 4 | tongliao
# Processing Record 38 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 4 | yialos
# City not found. Skipping...
# Processing Record 40 of Set 4 | pontian kecil
# Processing Record 41 of Set 4 | chokurdakh
# Processing Record 42 of Set 4 | tamiahua
# Processing Record 43 of Set 4 | souillac
# Processing Record 44 of Set 4 | yendi
# Processing Record 45 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 4 | laguna
# Processing Record 47 of Set 4 | burnie
# Processing Record 48 of Set 4 | menongue
# Processing Record 49 of Set 4 | saint austell
# Processing Record 50 of Set 4 | mosquera
# Processing Record 1 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 5 | nelson bay
# Processing Record 3 of Set 5 | manokwari
# Processing Record 4 of Set 5 | deputatskiy
# Processing Record 5 of Set 5 | avarua
# Processing Record 6 of Set 5 | sesheke
# Processing Record 7 of Set 5 | maloy
# Processing Record 8 of Set 5 | mahebourg
# Processing Record 9 of Set 5 | elliot
# Processing Record 10 of Set 5 | ambilobe
# Processing Record 11 of Set 5 | nikolskoye
# Processing Record 12 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 5 | carroll
# Processing Record 14 of Set 5 | pionerskiy
# Processing Record 15 of Set 5 | ostrovnoy
# Processing Record 16 of Set 5 | sirohi
# Processing Record 17 of Set 5 | powell river
# Processing Record 18 of Set 5 | guerrero negro
# Processing Record 19 of Set 5 | bougouni
# Processing Record 20 of Set 5 | ponta do sol
# Processing Record 21 of Set 5 | san vicente
# Processing Record 22 of Set 5 | magomeni
# Processing Record 23 of Set 5 | lesnoy
# Processing Record 24 of Set 5 | sfantu gheorghe
# Processing Record 25 of Set 5 | pangai
# Processing Record 26 of Set 5 | nanortalik
# Processing Record 27 of Set 5 | alofi
# Processing Record 28 of Set 5 | cherskiy
# Processing Record 29 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 5 | kangaatsiaq
# Processing Record 31 of Set 5 | plerin
# Processing Record 32 of Set 5 | balkhash
# Processing Record 33 of Set 5 | belaya gora
# Processing Record 34 of Set 5 | tangshan
# Processing Record 35 of Set 5 | tautira
# Processing Record 36 of Set 5 | aswan
# Processing Record 37 of Set 5 | kampong thum
# Processing Record 38 of Set 5 | ous
# Processing Record 39 of Set 5 | marzuq
# Processing Record 40 of Set 5 | abonnema
# Processing Record 41 of Set 5 | kenai
# Processing Record 42 of Set 5 | puerto quijarro
# Processing Record 43 of Set 5 | marsabit
# Processing Record 44 of Set 5 | pascagoula
# Processing Record 45 of Set 5 | kokkola
# Processing Record 46 of Set 5 | tiksi
# Processing Record 47 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 48 of Set 5 | ayr
# Processing Record 49 of Set 5 | great falls
# Processing Record 50 of Set 5 | padang
# Processing Record 1 of Set 6 | zalantun
# Processing Record 2 of Set 6 | khatanga
# Processing Record 3 of Set 6 | chunoyar
# Processing Record 4 of Set 6 | mount isa
# Processing Record 5 of Set 6 | marawi
# Processing Record 6 of Set 6 | namatanai
# Processing Record 7 of Set 6 | dandong
# Processing Record 8 of Set 6 | manzanillo
# Processing Record 9 of Set 6 | ringebu
# Processing Record 10 of Set 6 | mayo
# Processing Record 11 of Set 6 | narasaraopet
# Processing Record 12 of Set 6 | sonoita
# Processing Record 13 of Set 6 | victoria
# Processing Record 14 of Set 6 | raudeberg
# Processing Record 15 of Set 6 | pangody
# Processing Record 16 of Set 6 | aguimes
# Processing Record 17 of Set 6 | mehamn
# Processing Record 18 of Set 6 | ribeira grande
# Processing Record 19 of Set 6 | kallidaikurichchi
# Processing Record 20 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 6 | agadir
# Processing Record 22 of Set 6 | sayat
# Processing Record 23 of Set 6 | minab
# Processing Record 24 of Set 6 | opuwo
# Processing Record 25 of Set 6 | ambanja
# Processing Record 26 of Set 6 | verkhnetulomskiy
# Processing Record 27 of Set 6 | zaysan
# Processing Record 28 of Set 6 | turukhansk
# Processing Record 29 of Set 6 | saint george
# Processing Record 30 of Set 6 | isla mujeres
# Processing Record 31 of Set 6 | bozova
# Processing Record 32 of Set 6 | sistranda
# Processing Record 33 of Set 6 | busilac
# Processing Record 34 of Set 6 | alihe
# Processing Record 35 of Set 6 | bontang
# Processing Record 36 of Set 6 | pevek
# Processing Record 37 of Set 6 | kiruna
# Processing Record 38 of Set 6 | aksarka
# Processing Record 39 of Set 6 | mangrol
# Processing Record 40 of Set 6 | ust-kuyga
# Processing Record 41 of Set 6 | caravelas
# Processing Record 42 of Set 6 | santa marta
# Processing Record 43 of Set 6 | cayenne
# Processing Record 44 of Set 6 | hamilton
# Processing Record 45 of Set 6 | sorong
# Processing Record 46 of Set 6 | levelland
# Processing Record 47 of Set 6 | saint-louis
# Processing Record 48 of Set 6 | razam
# Processing Record 49 of Set 6 | broome
# Processing Record 50 of Set 6 | kerewan
# Processing Record 1 of Set 7 | phalombe
# Processing Record 2 of Set 7 | arlit
# Processing Record 3 of Set 7 | guantanamo
# Processing Record 4 of Set 7 | mafinga
# Processing Record 5 of Set 7 | rawson
# Processing Record 6 of Set 7 | hithadhoo
# Processing Record 7 of Set 7 | vila
# Processing Record 8 of Set 7 | maniitsoq
# Processing Record 9 of Set 7 | daru
# Processing Record 10 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 7 | leningradskiy
# Processing Record 12 of Set 7 | upata
# Processing Record 13 of Set 7 | kikinda
# Processing Record 14 of Set 7 | vostok
# Processing Record 15 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 16 of Set 7 | tura
# Processing Record 17 of Set 7 | saint-augustin
# Processing Record 18 of Set 7 | gizo
# Processing Record 19 of Set 7 | angoche
# Processing Record 20 of Set 7 | eirunepe
# Processing Record 21 of Set 7 | chicama
# Processing Record 22 of Set 7 | camacha
# Processing Record 23 of Set 7 | tigil
# Processing Record 24 of Set 7 | chala
# Processing Record 25 of Set 7 | terney
# Processing Record 26 of Set 7 | la palma
# Processing Record 27 of Set 7 | pesaro
# Processing Record 28 of Set 7 | launceston
# Processing Record 29 of Set 7 | severo-kurilsk
# Processing Record 30 of Set 7 | luderitz
# Processing Record 31 of Set 7 | panjakent
# Processing Record 32 of Set 7 | adelaide
# Processing Record 33 of Set 7 | palanga
# Processing Record 34 of Set 7 | charters towers
# Processing Record 35 of Set 7 | hohhot
# Processing Record 36 of Set 7 | caraquet
# Processing Record 37 of Set 7 | goure
# Processing Record 38 of Set 7 | aklavik
# Processing Record 39 of Set 7 | marsa matruh
# Processing Record 40 of Set 7 | zeya
# Processing Record 41 of Set 7 | shimoda
# Processing Record 42 of Set 7 | tagusao
# Processing Record 43 of Set 7 | nyurba
# Processing Record 44 of Set 7 | acari
# Processing Record 45 of Set 7 | filadelfia
# Processing Record 46 of Set 7 | oriximina
# Processing Record 47 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 48 of Set 7 | mayor pablo lagerenza
# Processing Record 49 of Set 7 | magugu
# Processing Record 50 of Set 7 | golden
# Processing Record 1 of Set 8 | salinopolis
# Processing Record 2 of Set 8 | peniche
# Processing Record 3 of Set 8 | poyarkovo
# Processing Record 4 of Set 8 | freetown
# Processing Record 5 of Set 8 | kirakira
# Processing Record 6 of Set 8 | nizhniy kuranakh
# Processing Record 7 of Set 8 | mitchell
# Processing Record 8 of Set 8 | abbeville
# Processing Record 9 of Set 8 | merauke
# Processing Record 10 of Set 8 | buchanan
# Processing Record 11 of Set 8 | awbari
# Processing Record 12 of Set 8 | tilichiki
# Processing Record 13 of Set 8 | ahipara
# Processing Record 14 of Set 8 | port augusta
# Processing Record 15 of Set 8 | coihaique
# Processing Record 16 of Set 8 | noumea
# Processing Record 17 of Set 8 | simpang
# Processing Record 18 of Set 8 | aden
# Processing Record 19 of Set 8 | tandil
# Processing Record 20 of Set 8 | champerico
# Processing Record 21 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 8 | ampanihy
# Processing Record 23 of Set 8 | eregli
# Processing Record 24 of Set 8 | polson
# Processing Record 25 of Set 8 | winslow
# Processing Record 26 of Set 8 | houston
# Processing Record 27 of Set 8 | sao jose da coroa grande
# Processing Record 28 of Set 8 | fukue
# Processing Record 29 of Set 8 | hay river
# Processing Record 30 of Set 8 | fomboni
# Processing Record 31 of Set 8 | trinidad
# Processing Record 32 of Set 8 | nemuro
# Processing Record 33 of Set 8 | half moon bay
# Processing Record 34 of Set 8 | bambous virieux
# Processing Record 35 of Set 8 | san rafael
# Processing Record 36 of Set 8 | antofagasta
# Processing Record 37 of Set 8 | ouro preto do oeste
# Processing Record 38 of Set 8 | bowral
# Processing Record 39 of Set 8 | port lincoln
# Processing Record 40 of Set 8 | timra
# Processing Record 41 of Set 8 | richards bay
# Processing Record 42 of Set 8 | port macquarie
# Processing Record 43 of Set 8 | fortuna
# Processing Record 44 of Set 8 | slupsk
# Processing Record 45 of Set 8 | bubaque
# Processing Record 46 of Set 8 | blackfoot
# Processing Record 47 of Set 8 | kitami
# Processing Record 48 of Set 8 | tateyama
# Processing Record 49 of Set 8 | oktyabrskiy
# Processing Record 50 of Set 8 | ouadda
# Processing Record 1 of Set 9 | mareeba
# Processing Record 2 of Set 9 | camocim
# Processing Record 3 of Set 9 | tarko-sale
# Processing Record 4 of Set 9 | kieta
# Processing Record 5 of Set 9 | meadow lake
# Processing Record 6 of Set 9 | swan hill
# Processing Record 7 of Set 9 | birao
# Processing Record 8 of Set 9 | pamekasan
# Processing Record 9 of Set 9 | kungurtug
# Processing Record 10 of Set 9 | tarakan
# Processing Record 11 of Set 9 | sharkan
# Processing Record 12 of Set 9 | lekoni
# Processing Record 13 of Set 9 | tessalit
# Processing Record 14 of Set 9 | domoni
# Processing Record 15 of Set 9 | los zacatones
# Processing Record 16 of Set 9 | greytown
# Processing Record 17 of Set 9 | berlevag
# Processing Record 18 of Set 9 | progreso
# Processing Record 19 of Set 9 | broken hill
# Processing Record 20 of Set 9 | envira
# Processing Record 21 of Set 9 | kommunisticheskiy
# Processing Record 22 of Set 9 | sola
# Processing Record 23 of Set 9 | kawai
# Processing Record 24 of Set 9 | talnakh
# Processing Record 25 of Set 9 | sur
# Processing Record 26 of Set 9 | tiarei
# Processing Record 27 of Set 9 | ponta delgada
# Processing Record 28 of Set 9 | sapa
# Processing Record 29 of Set 9 | sheksna
# Processing Record 30 of Set 9 | phalaborwa
# Processing Record 31 of Set 9 | okhotsk
# Processing Record 32 of Set 9 | strelice
# Processing Record 33 of Set 9 | koshurnikovo
# Processing Record 34 of Set 9 | belleville
# Processing Record 35 of Set 9 | touros
# Processing Record 36 of Set 9 | faya
# Processing Record 37 of Set 9 | islamkot
# Processing Record 38 of Set 9 | antakya
# Processing Record 39 of Set 9 | turka
# Processing Record 40 of Set 9 | richmond west
# Processing Record 41 of Set 9 | oyama
# Processing Record 42 of Set 9 | coahuayana
# Processing Record 43 of Set 9 | san carlos de bariloche
# Processing Record 44 of Set 9 | azar shahr
# City not found. Skipping...
# Processing Record 45 of Set 9 | umm lajj
# Processing Record 46 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 9 | moindou
# Processing Record 48 of Set 9 | barroualie
# City not found. Skipping...
# Processing Record 49 of Set 9 | san quintin
# Processing Record 50 of Set 9 | aykhal
# Processing Record 1 of Set 10 | meulaboh
# Processing Record 2 of Set 10 | sitka
# Processing Record 3 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 10 | mecca
# Processing Record 5 of Set 10 | nueva armenia
# Processing Record 6 of Set 10 | nur
# Processing Record 7 of Set 10 | verkhoyansk
# Processing Record 8 of Set 10 | kavieng
# Processing Record 9 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 10 of Set 10 | phan thiet
# Processing Record 11 of Set 10 | nueva guinea
# Processing Record 12 of Set 10 | anloga
# Processing Record 13 of Set 10 | leshukonskoye
# Processing Record 14 of Set 10 | beringovskiy
# Processing Record 15 of Set 10 | cabo san lucas
# Processing Record 16 of Set 10 | guider
# Processing Record 17 of Set 10 | torrington
# Processing Record 18 of Set 10 | kulhudhuffushi
# Processing Record 19 of Set 10 | kavaratti
# Processing Record 20 of Set 10 | boffa
# Processing Record 21 of Set 10 | bilma
# Processing Record 22 of Set 10 | zhangye
# Processing Record 23 of Set 10 | dillon
# Processing Record 24 of Set 10 | pisco
# Processing Record 25 of Set 10 | geraldton
# Processing Record 26 of Set 10 | wexford
# Processing Record 27 of Set 10 | cheremukhovo
# Processing Record 28 of Set 10 | arrah
# Processing Record 29 of Set 10 | salym
# Processing Record 30 of Set 10 | nichinan
# Processing Record 31 of Set 10 | alyangula
# Processing Record 32 of Set 10 | fort nelson
# Processing Record 33 of Set 10 | kharitonovo
# Processing Record 34 of Set 10 | celestun
# Processing Record 35 of Set 10 | kahului
# Processing Record 36 of Set 10 | san cristobal
# Processing Record 37 of Set 10 | maragogi
# Processing Record 38 of Set 10 | jinchang
# Processing Record 39 of Set 10 | hofn
# Processing Record 40 of Set 10 | tutoia
# Processing Record 41 of Set 10 | qui nhon
# Processing Record 42 of Set 10 | havre-saint-pierre
# Processing Record 43 of Set 10 | glendive
# Processing Record 44 of Set 10 | mouzouras
# Processing Record 45 of Set 10 | oranjemund
# Processing Record 46 of Set 10 | nortelandia
# Processing Record 47 of Set 10 | vigrestad
# Processing Record 48 of Set 10 | sakakah
# Processing Record 49 of Set 10 | haines junction
# Processing Record 50 of Set 10 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 1 of Set 11 | hobyo
# Processing Record 2 of Set 11 | kodino
# Processing Record 3 of Set 11 | cadereyta
# Processing Record 4 of Set 11 | bathsheba
# Processing Record 5 of Set 11 | ukiah
# Processing Record 6 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 7 of Set 11 | dubasari
# Processing Record 8 of Set 11 | bhuban
# Processing Record 9 of Set 11 | beisfjord
# Processing Record 10 of Set 11 | coquimbo
# Processing Record 11 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 12 of Set 11 | parkville
# Processing Record 13 of Set 11 | jackson
# Processing Record 14 of Set 11 | dingle
# Processing Record 15 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 11 | waingapu
# Processing Record 17 of Set 11 | awjilah
# Processing Record 18 of Set 11 | port hedland
# Processing Record 19 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 11 | tolmin
# Processing Record 21 of Set 11 | sisimiut
# Processing Record 22 of Set 11 | poum
# Processing Record 23 of Set 11 | ozernovskiy
# Processing Record 24 of Set 11 | koulikoro
# Processing Record 25 of Set 11 | tulum
# Processing Record 26 of Set 11 | bom jesus
# Processing Record 27 of Set 11 | shepsi
# Processing Record 28 of Set 11 | yola
# Processing Record 29 of Set 11 | praia da vitoria
# Processing Record 30 of Set 11 | wete
# Processing Record 31 of Set 11 | lagos
# Processing Record 32 of Set 11 | lasa
# Processing Record 33 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 11 | el dorado
# Processing Record 35 of Set 11 | tukan
# Processing Record 36 of Set 11 | inhambane
# Processing Record 37 of Set 11 | harper
# Processing Record 38 of Set 11 | kyshtovka
# Processing Record 39 of Set 11 | quatre cocos
# Processing Record 40 of Set 11 | chimoio
# Processing Record 41 of Set 11 | lincoln
# Processing Record 42 of Set 11 | huarmey
# Processing Record 43 of Set 11 | copiapo
# Processing Record 44 of Set 11 | robat karim
# Processing Record 45 of Set 11 | arecibo
# Processing Record 46 of Set 11 | atar
# Processing Record 47 of Set 11 | mukhen
# Processing Record 48 of Set 11 | ouanaminthe
# Processing Record 49 of Set 11 | bethanien
# Processing Record 50 of Set 11 | curup
# Processing Record 1 of Set 12 | north bend
# Processing Record 2 of Set 12 | rafaela
# Processing Record 3 of Set 12 | bridlington
# Processing Record 4 of Set 12 | kokopo
# Processing Record 5 of Set 12 | takoradi
# Processing Record 6 of Set 12 | shaunavon
# Processing Record 7 of Set 12 | sujawal
# City not found. Skipping...
# Processing Record 8 of Set 12 | coolum beach
# Processing Record 9 of Set 12 | taltal
# Processing Record 10 of Set 12 | puerto maldonado
# Processing Record 11 of Set 12 | flin flon
# Processing Record 12 of Set 12 | majene
# Processing Record 13 of Set 12 | oussouye
# Processing Record 14 of Set 12 | shakiso
# Processing Record 15 of Set 12 | agua prieta
# Processing Record 16 of Set 12 | general roca
# Processing Record 17 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 12 | wuxue
# Processing Record 19 of Set 12 | nixa
# Processing Record 20 of Set 12 | araouane
# Processing Record 21 of Set 12 | ati
# Processing Record 22 of Set 12 | astoria
# Processing Record 23 of Set 12 | lavrentiya
# Processing Record 24 of Set 12 | wilmington island
# Processing Record 25 of Set 12 | zhitikara
# City not found. Skipping...
# Processing Record 26 of Set 12 | les escoumins
# Processing Record 27 of Set 12 | carutapera
# Processing Record 28 of Set 12 | tirumullaivasal
# Processing Record 29 of Set 12 | xingcheng
# Processing Record 30 of Set 12 | bud
# Processing Record 31 of Set 12 | cabedelo
# Processing Record 32 of Set 12 | rodrigues alves
# Processing Record 33 of Set 12 | dispur
# Processing Record 34 of Set 12 | jalu
# Processing Record 35 of Set 12 | gariaband
# Processing Record 36 of Set 12 | christchurch
# Processing Record 37 of Set 12 | araioses
# Processing Record 38 of Set 12 | gerash
# Processing Record 39 of Set 12 | margate
# Processing Record 40 of Set 12 | berbera
# Processing Record 41 of Set 12 | shush
# Processing Record 42 of Set 12 | palu
# Processing Record 43 of Set 12 | fukuma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 552

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Vaini -21.2000 -175.2000     23.09       100          40
# 1        Klaksvik  62.2266   -6.5890      9.51        77           1
# 2         Ushuaia -54.8000  -68.3000     12.79        62          20
# 3        Noyabrsk  63.1994   75.4507      4.14        84         100
# 4  Virginia Beach  36.8529  -75.9780     12.25        91         100
# 5         Xixiang  35.1628  112.8650      8.02        81         100
# 6     Kapuskasing  49.4169  -82.4331     15.84        71          98
# 7          Yulara -25.2406  130.9889     16.50        48           0
# 8         Mataura -46.1927  168.8643      1.29        99         100
# 9        Lorengau  -2.0226  147.2712     27.59        80          99
#
#    Wind Speed Country Weather Description
# 0        2.06      TO    scattered clouds
# 1       18.31      FO           clear sky
# 2        0.51      AR          few clouds
# 3        5.48      RU     overcast clouds
# 4        5.14      US     overcast clouds
# 5        0.98      CN     overcast clouds
# 6        2.36      CA     overcast clouds
# 7        4.36      AU           clear sky
# 8        2.08      NZ                snow
# 9        4.32      PG     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
city_data_df = city_data_df.rename(columns={"Weather Description": "Current Description"})

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Vaini      TO -21.2000 -175.2000     23.09       100          40
# 1        Klaksvik      FO  62.2266   -6.5890      9.51        77           1
# 2         Ushuaia      AR -54.8000  -68.3000     12.79        62          20
# 3        Noyabrsk      RU  63.1994   75.4507      4.14        84         100
# 4  Virginia Beach      US  36.8529  -75.9780     12.25        91         100
# 5         Xixiang      CN  35.1628  112.8650      8.02        81         100
# 6     Kapuskasing      CA  49.4169  -82.4331     15.84        71          98
# 7          Yulara      AU -25.2406  130.9889     16.50        48           0
# 8         Mataura      NZ -46.1927  168.8643      1.29        99         100
# 9        Lorengau      PG  -2.0226  147.2712     27.59        80          99
#
#    Wind Speed Current Description
# 0        2.06    scattered clouds
# 1       18.31           clear sky
# 2        0.51          few clouds
# 3        5.48     overcast clouds
# 4        5.14     overcast clouds
# 5        0.98     overcast clouds
# 6        2.36     overcast clouds
# 7        4.36           clear sky
# 8        2.08                snow
# 9        4.32     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="Weather_Database")
